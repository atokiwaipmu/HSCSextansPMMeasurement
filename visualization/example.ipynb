# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
base_dir = "/Users/akiratokiwa/workspace/Sextans_final/"
ms_ccut = pd.read_csv(f'{base_dir}catalog/product/starall_HSCS21a_PI_ccut.csv')

# %%
params_dir=f'{base_dir}params_estimated/'
psamples = np.loadtxt(params_dir + "plum.txt")
ksamples = np.loadtxt(params_dir + "king.txt")
esamples = np.loadtxt(params_dir + "expo.txt")

# %%
plt.hist(ksamples[:,2], bins=100, histtype="step", label="King", density=True)
plt.hist(psamples[:,2], bins=100, histtype="step", label="Plummer", density=True)
plt.hist(esamples[:,2], bins=100, histtype="step", label="Exponential", density=True)
plt.xlabel("N")
plt.ylabel("Probability")
plt.legend()
plt.show()
